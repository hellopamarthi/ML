# %% [markdown]
# <a href="https://colab.research.google.com/github/hellopamarthi/ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
## 0 means rowns
df.shape[0]
# Out:
# 78

# %%
## 1 means columns
df.shape[1]
# Out:
# 6

# %%
##both the rows and columns together. 
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
##mean for top 50 rows

df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
##standard deviattion

df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
##describe on whole dataset
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
##describe on specific column data set
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
## individual column Mathementical operations(Mean, count..etc)

df['phd'].count()
# Out:
# 78

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
##Groupby 'Rank Attribute'

df_rank=df.groupby(['rank'])

# %%
df_rank.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613

# %%
##Mean for all the Measures based on Rank Grouping. 
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
##Mean for salary Measures based on Rank Grouping. 
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[(df['phd']>=20) & (df['discipline']=="A")]
# Out:
#          rank discipline  phd  service     sex  salary
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 32       Prof          A   27       19    Male  103275
# 37       Prof          A   20        8    Male  102000
# 40       Prof          A   39       36  Female  137000
# 54  AssocProf          A   25       22  Female   62884
# 63       Prof          A   29       27  Female   91000
# ...

# %%
## 4 Columns are represetned.
df.iloc[:,0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# ..        ...        ...  ...      ...
# 73       Prof          B   18       10
# 74  AssocProf          B   19        6
# 75       Prof          B   17       17
# 76       Prof          A   28       14
# 77       Prof          A   23       15
#
# [78 rows x 4 columns]

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
## 4 Rows are represetned.
df.iloc[0:4,:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
## 50 Rows & columns of 2,3,5are represetned.

df.iloc[0:50,[2,3,5]]
# Out:
#     phd  service  salary
# 0    56       49  186960
# 1    12        6   93000
# 2    23       20  110515
# 3    40       31  131205
# 4    20       18  104800
# 5    20       20  122400
# 6    20       17   81285
# 7    18       18  126300
# 8    29       19   94350
# 9    51       51   57800
# 10   39       33  128250
# 11   23       23  134778
# 12    1        0   88000
# 13   35       33  162200
# 14   25       19  153750
# 15   17        3  150480
# 16    8        3   75044
# 17    4        0   92000
# 18   19        7  107300
# 19   29       27  150500
# 20    4        4   92000
# 21   33       30  103106
# 22    4        2   73000
# 23    2        0   85000
# 24   30       23   91100
# 25   35       31   99418
# 26   38       19  148750
# 27   45       43  155865
# 28    7        2   91300
# 29   21       20  123683
# 30    9        7  107008
# 31   22       21  155750
# 32   27       19  103275
# 33   18       18  120000
# 34   12        8  119800
# 35   28       23  126933
# ...

# %%
df[['phd','salary']].agg(['min','max','mean'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051

# %% [markdown]
# 24072021

# %%
from scipy import stats

# %%
stats.norm.cdf(70,loc=60,scale=10)
# Out:
# 0.8413447460685429
